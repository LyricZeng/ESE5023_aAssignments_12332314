# %%
#5.Dynamic programming
#5.1
from tqdm import *#进度条
import itertools
import numpy as np  
A = np.random.randint(1, 100)
def Find_expression(A: int, nums: str) -> list:  
    opra = ['+', '-', '']  
    def find_all(nums: str) -> list:  
        if len(nums) == 1:  
            return [nums]  
        else:  
            return [nums[0] + j + i for i in find_all(nums[1:]) for j in opra]        
    # 生成所有可能的组合  
    all_combinations = list(itertools.product(opra, repeat=len(nums)))   
    # 过滤出满足条件的表达式  
    results = [k + '=' + str(A) for k in find_all(nums) if eval(k) == A]       
    return results
if __name__ == "__main__":  
    results = {}
    for a in tqdm(range(1,101)):
        result = Find_expression(a, "123456789")  
        results[a] = result
print(results)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  8.73it/s]
# ...

# %%
#5.2
from tqdm import *#进度条
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Arial' # Arial 英文格式,SimHei黑体
y = np.full(100,np.nan)
for i in tqdm(range(100)):
    y[i]=len(results[i+1])
x = range(1,101)
fig = plt.figure(figsize=(4,3))
plt.plot(x, y)
plt.xticks(np.array([0, 19,  39,  59,  79, 99]), labels=np.array([0, 20,  40,  60,  80, 100]))# 设置x轴刻度和标签
plt.xlabel("number")
plt.ylabel("numbers of answer")
plt.title("Total_solutions")
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 341000.33it/s]
